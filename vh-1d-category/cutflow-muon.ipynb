# %%
import os, subprocess
import json
import uproot
import awkward as ak
import numpy as np
from coffea import processor, util, hist

# %matplotlib inline
import matplotlib.pyplot as plt
from cycler import cycler

import mplhep as hep
plt.style.use([hep.style.ROOT, hep.style.CMS])

# %%
colors = {}
colors['QCD'] = '#1f77b4'
colors['VBF'] = '#ff7f0e'
colors['VV'] = '#2ca02c'
colors['Wjets'] = '#d62728'
colors['WH'] = '#9467bd'
colors['Zjets'] = '#8c564b'
colors['ZH'] = '#e377c2'
colors['ggF'] = '#7f7f7f'
colors['ttbar'] = '#bcdb22'
colors['singlet'] = '#bcdb22'
colors['ttH'] = '#17becf'

# %%
lumis = {}
lumis['2016'] = 35.9
lumis['2017'] = 41.1
lumis['2018'] = 59.9

nfiles_mc = {}
nfiles_mc['2016'] = 113
nfiles_mc['2017'] = 167
nfiles_mc['2018'] = 201

nfiles_data = {}
nfiles_data['2016'] = 101
nfiles_data['2017'] = 97
nfiles_data['2018'] = 133

with open('xsec.json') as f:
    xs = json.load(f)

with open('pmap.json') as f:
    pmap = json.load(f)

# %%
year = '2016'
outsum = processor.dict_accumulator()

# %%
# Load all MC
for n in range(1,nfiles_mc[year]+1):
    print(n)
    filename = 'outfiles/'+year+'_'+str(n)+'.coffea'
    if os.path.isfile(filename):
        out = util.load(filename)
        outsum.add(out)
    else:
        print("File " + filename + " is missing")
        
scale_lumi = {k: xs[k] * 1000 *lumis[year] / w for k, w in outsum['sumw'].items()}
outsum['cutflow'].scale(scale_lumi, 'dataset')
outsum['templates1'].scale(scale_lumi, 'dataset')
outsum['templates2'].scale(scale_lumi, 'dataset')
# Out:
# 1
# File outfiles/2016_1.coffea is missing
# 2
# File outfiles/2016_2.coffea is missing
# 3
# File outfiles/2016_3.coffea is missing
# 4
# File outfiles/2016_4.coffea is missing
# 5
# File outfiles/2016_5.coffea is missing
# 6
# File outfiles/2016_6.coffea is missing
# 7
# File outfiles/2016_7.coffea is missing
# 8
# File outfiles/2016_8.coffea is missing
# 9
# File outfiles/2016_9.coffea is missing
# 10
# File outfiles/2016_10.coffea is missing
# 11
# File outfiles/2016_11.coffea is missing
# 12
# File outfiles/2016_12.coffea is missing
# 13
# File outfiles/2016_13.coffea is missing
# 14
# File outfiles/2016_14.coffea is missing
# 15
# File outfiles/2016_15.coffea is missing
# 16
# File outfiles/2016_16.coffea is missing
# 17
# File outfiles/2016_17.coffea is missing
# 18
# File outfiles/2016_18.coffea is missing
# 19
# File outfiles/2016_19.coffea is missing
# 20
# File outfiles/2016_20.coffea is missing
# 21
# File outfiles/2016_21.coffea is missing
# 22
# File outfiles/2016_22.coffea is missing
# 23
# File outfiles/2016_23.coffea is missing
# 24
# File outfiles/2016_24.coffea is missing
# 25
# File outfiles/2016_25.coffea is missing
# 26
# File outfiles/2016_26.coffea is missing
# 27
# File outfiles/2016_27.coffea is missing
# 28
# File outfiles/2016_28.coffea is missing
# 29
# File outfiles/2016_29.coffea is missing
# 30
# File outfiles/2016_30.coffea is missing
# 31
# File outfiles/2016_31.coffea is missing
# 32
# File outfiles/2016_32.coffea is missing
# 33
# File outfiles/2016_33.coffea is missing
# 34
# File outfiles/2016_34.coffea is missing
# 35
# File outfiles/2016_35.coffea is missing
# 36
# File outfiles/2016_36.coffea is missing
# 37
# File outfiles/2016_37.coffea is missing
# 38
# File outfiles/2016_38.coffea is missing
# 39
# File outfiles/2016_39.coffea is missing
# 40
# File outfiles/2016_40.coffea is missing
# 41
# File outfiles/2016_41.coffea is missing
# 42
# File outfiles/2016_42.coffea is missing
# 43
# File outfiles/2016_43.coffea is missing
# 44
# File outfiles/2016_44.coffea is missing
# 45
# File outfiles/2016_45.coffea is missing
# 46
# File outfiles/2016_46.coffea is missing
# 47
# File outfiles/2016_47.coffea is missing
# 48
# File outfiles/2016_48.coffea is missing
# 49
# File outfiles/2016_49.coffea is missing
# 50
# File outfiles/2016_50.coffea is missing
# 51
# File outfiles/2016_51.coffea is missing
# 52
# File outfiles/2016_52.coffea is missing
# 53
# File outfiles/2016_53.coffea is missing
# 54
# File outfiles/2016_54.coffea is missing
# 55
# File outfiles/2016_55.coffea is missing
# 56
# File outfiles/2016_56.coffea is missing
# 57
# File outfiles/2016_57.coffea is missing
# 58
# File outfiles/2016_58.coffea is missing
# 59
# File outfiles/2016_59.coffea is missing
# 60
# File outfiles/2016_60.coffea is missing
# 61
# File outfiles/2016_61.coffea is missing
# 62
# File outfiles/2016_62.coffea is missing
# 63
# File outfiles/2016_63.coffea is missing
# 64
# File outfiles/2016_64.coffea is missing
# 65
# File outfiles/2016_65.coffea is missing
# 66
# File outfiles/2016_66.coffea is missing
# 67
# File outfiles/2016_67.coffea is missing
# 68
# File outfiles/2016_68.coffea is missing
# 69
# File outfiles/2016_69.coffea is missing
# 70
# File outfiles/2016_70.coffea is missing
# 71
# File outfiles/2016_71.coffea is missing
# 72
# File outfiles/2016_72.coffea is missing
# 73
# File outfiles/2016_73.coffea is missing
# 74
# File outfiles/2016_74.coffea is missing
# 75
# File outfiles/2016_75.coffea is missing
# 76
# File outfiles/2016_76.coffea is missing
# 77
# File outfiles/2016_77.coffea is missing
# 78
# File outfiles/2016_78.coffea is missing
# 79
# File outfiles/2016_79.coffea is missing
# 80
# File outfiles/2016_80.coffea is missing
# 81
# File outfiles/2016_81.coffea is missing
# 82
# File outfiles/2016_82.coffea is missing
# 83
# 84
# File outfiles/2016_84.coffea is missing
# 85
# File outfiles/2016_85.coffea is missing
# 86
# File outfiles/2016_86.coffea is missing
# 87
# File outfiles/2016_87.coffea is missing
# 88
# File outfiles/2016_88.coffea is missing
# 89
# File outfiles/2016_89.coffea is missing
# 90
# File outfiles/2016_90.coffea is missing
# 91
# File outfiles/2016_91.coffea is missing
# 92
# File outfiles/2016_92.coffea is missing
# 93
# File outfiles/2016_93.coffea is missing
# 94
# File outfiles/2016_94.coffea is missing
# 95
# File outfiles/2016_95.coffea is missing
# 96
# File outfiles/2016_96.coffea is missing
# 97
# File outfiles/2016_97.coffea is missing
# 98
# File outfiles/2016_98.coffea is missing
# 99
# File outfiles/2016_99.coffea is missing
# 100
# File outfiles/2016_100.coffea is missing
# 101
# File outfiles/2016_101.coffea is missing
# 102
# File outfiles/2016_102.coffea is missing
# 103
# File outfiles/2016_103.coffea is missing
# 104
# File outfiles/2016_104.coffea is missing
# 105
# File outfiles/2016_105.coffea is missing
# 106
# File outfiles/2016_106.coffea is missing
# 107
# File outfiles/2016_107.coffea is missing
# 108
# File outfiles/2016_108.coffea is missing
# 109
# File outfiles/2016_109.coffea is missing
# 110
# File outfiles/2016_110.coffea is missing
# 111
# File outfiles/2016_111.coffea is missing
# 112
# File outfiles/2016_112.coffea is missing
# 113
# File outfiles/2016_113.coffea is missing

# %%
# Load all data
for n in range(1,nfiles_data[year]+1):
    print(n)
    filename = 'outdata/'+year+'_'+str(n)+'.coffea'
    if os.path.isfile(filename):
        out = util.load(filename)
        outsum.add(out)
    else:
        print("File " + filename + " is missing")
        
# BE CAREFUL NOT TO UNBLIND
# Can you figure out how to blind it at this step???
# Out:
# 1
# File outdata/2016_1.coffea is missing
# 2
# File outdata/2016_2.coffea is missing
# 3
# File outdata/2016_3.coffea is missing
# 4
# File outdata/2016_4.coffea is missing
# 5
# File outdata/2016_5.coffea is missing
# 6
# File outdata/2016_6.coffea is missing
# 7
# File outdata/2016_7.coffea is missing
# 8
# File outdata/2016_8.coffea is missing
# 9
# File outdata/2016_9.coffea is missing
# 10
# File outdata/2016_10.coffea is missing
# 11
# File outdata/2016_11.coffea is missing
# 12
# File outdata/2016_12.coffea is missing
# 13
# File outdata/2016_13.coffea is missing
# 14
# File outdata/2016_14.coffea is missing
# 15
# File outdata/2016_15.coffea is missing
# 16
# File outdata/2016_16.coffea is missing
# 17
# File outdata/2016_17.coffea is missing
# 18
# File outdata/2016_18.coffea is missing
# 19
# File outdata/2016_19.coffea is missing
# 20
# File outdata/2016_20.coffea is missing
# 21
# File outdata/2016_21.coffea is missing
# 22
# File outdata/2016_22.coffea is missing
# 23
# File outdata/2016_23.coffea is missing
# 24
# File outdata/2016_24.coffea is missing
# 25
# File outdata/2016_25.coffea is missing
# 26
# File outdata/2016_26.coffea is missing
# 27
# File outdata/2016_27.coffea is missing
# 28
# File outdata/2016_28.coffea is missing
# 29
# File outdata/2016_29.coffea is missing
# 30
# File outdata/2016_30.coffea is missing
# 31
# File outdata/2016_31.coffea is missing
# 32
# File outdata/2016_32.coffea is missing
# 33
# File outdata/2016_33.coffea is missing
# 34
# File outdata/2016_34.coffea is missing
# 35
# File outdata/2016_35.coffea is missing
# 36
# File outdata/2016_36.coffea is missing
# 37
# File outdata/2016_37.coffea is missing
# 38
# File outdata/2016_38.coffea is missing
# 39
# File outdata/2016_39.coffea is missing
# 40
# File outdata/2016_40.coffea is missing
# 41
# File outdata/2016_41.coffea is missing
# 42
# File outdata/2016_42.coffea is missing
# 43
# File outdata/2016_43.coffea is missing
# 44
# File outdata/2016_44.coffea is missing
# 45
# File outdata/2016_45.coffea is missing
# 46
# File outdata/2016_46.coffea is missing
# 47
# File outdata/2016_47.coffea is missing
# 48
# File outdata/2016_48.coffea is missing
# 49
# File outdata/2016_49.coffea is missing
# 50
# File outdata/2016_50.coffea is missing
# 51
# File outdata/2016_51.coffea is missing
# 52
# File outdata/2016_52.coffea is missing
# 53
# File outdata/2016_53.coffea is missing
# 54
# File outdata/2016_54.coffea is missing
# 55
# File outdata/2016_55.coffea is missing
# 56
# File outdata/2016_56.coffea is missing
# 57
# File outdata/2016_57.coffea is missing
# 58
# File outdata/2016_58.coffea is missing
# 59
# File outdata/2016_59.coffea is missing
# 60
# File outdata/2016_60.coffea is missing
# 61
# File outdata/2016_61.coffea is missing
# 62
# File outdata/2016_62.coffea is missing
# 63
# File outdata/2016_63.coffea is missing
# 64
# File outdata/2016_64.coffea is missing
# 65
# File outdata/2016_65.coffea is missing
# 66
# File outdata/2016_66.coffea is missing
# 67
# File outdata/2016_67.coffea is missing
# 68
# File outdata/2016_68.coffea is missing
# 69
# File outdata/2016_69.coffea is missing
# 70
# File outdata/2016_70.coffea is missing
# 71
# File outdata/2016_71.coffea is missing
# 72
# File outdata/2016_72.coffea is missing
# 73
# File outdata/2016_73.coffea is missing
# 74
# File outdata/2016_74.coffea is missing
# 75
# File outdata/2016_75.coffea is missing
# 76
# File outdata/2016_76.coffea is missing
# 77
# File outdata/2016_77.coffea is missing
# 78
# File outdata/2016_78.coffea is missing
# 79
# File outdata/2016_79.coffea is missing
# 80
# File outdata/2016_80.coffea is missing
# 81
# File outdata/2016_81.coffea is missing
# 82
# File outdata/2016_82.coffea is missing
# 83
# File outdata/2016_83.coffea is missing
# 84
# File outdata/2016_84.coffea is missing
# 85
# File outdata/2016_85.coffea is missing
# 86
# File outdata/2016_86.coffea is missing
# 87
# File outdata/2016_87.coffea is missing
# 88
# File outdata/2016_88.coffea is missing
# 89
# File outdata/2016_89.coffea is missing
# 90
# File outdata/2016_90.coffea is missing
# 91
# File outdata/2016_91.coffea is missing
# 92
# File outdata/2016_92.coffea is missing
# 93
# File outdata/2016_93.coffea is missing
# 94
# File outdata/2016_94.coffea is missing
# 95
# File outdata/2016_95.coffea is missing
# 96
# File outdata/2016_96.coffea is missing
# 97
# File outdata/2016_97.coffea is missing
# 98
# File outdata/2016_98.coffea is missing
# 99
# File outdata/2016_99.coffea is missing
# 100
# File outdata/2016_100.coffea is missing
# 101
# File outdata/2016_101.coffea is missing

# %%
templates = outsum['cutflow'].group('dataset', hist.Cat('process', 'Process'), pmap)
# Out:
# /uscms_data/d3/jennetd/hbb-prod-modes/february-2021/vh-1d-category/coffeaenv/lib/python3.7/site-packages/coffea/hist/hist_tools.py:347: RuntimeWarning: Not all requested indices present in <Cat (name=dataset) instance at 0x7f4440321fd0>
#   warnings.warn("Not all requested indices present in %r" % self, RuntimeWarning)

# %%
cutflow = templates.sum('genflavor').integrate('region','muoncontrol').integrate('process','muondata')
cutflow.values()
# Out:
# {}

# %%
cutflow = templates.sum('genflavor').integrate('region','muoncontrol').integrate('process','ttbar')
cutflow.values()
# Out:
# {(): array([1.21563365e+07, 1.21563365e+07, 4.16847688e+04, 2.74046330e+04,
#         2.74046330e+04, 5.28688927e+03, 2.94926826e+03, 1.75268174e+03,
#         2.47689196e+02, 2.98692652e+01, 0.00000000e+00])}

# %%
templates1 = outsum['templates1'].group('dataset', hist.Cat('process', 'Process'), pmap).integrate('region','muoncontrol')
# Out:
# /uscms_data/d3/jennetd/hbb-prod-modes/february-2021/vh-1d-category/coffeaenv/lib/python3.7/site-packages/coffea/hist/hist_tools.py:347: RuntimeWarning: Not all requested indices present in <Cat (name=dataset) instance at 0x7f4440324bd0>
#   warnings.warn("Not all requested indices present in %r" % self, RuntimeWarning)

# %%
hist.plot1d(templates1.sum('pt1').integrate('process','muondata'),overlay='ddb1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-a380b860072d> in <module>
# ----> 1 hist.plot1d(templates1.sum('pt1').integrate('process','muondata'),overlay='ddb1')
#
# /uscms_data/d3/jennetd/hbb-prod-modes/february-2021/vh-1d-category/coffeaenv/lib/python3.7/site-packages/coffea/hist/hist_tools.py in sum(self, *axes, **kwargs)
#    1013         """
#    1014         overflow = kwargs.pop('overflow', 'none')
# -> 1015         axes = [self.axis(ax) for ax in axes]
#    1016         reduced_dims = [ax for ax in self._axes if ax not in axes]
#    1017         out = Hist(self._label, *reduced_dims, dtype=self._dtype)
#
# /uscms_data/d3/jennetd/hbb-prod-modes/february-2021/vh-1d-category/coffeaenv/lib/python3.7/site-packages/coffea/hist/hist_tools.py in <listcomp>(.0)
#    1013         """
#    1014         overflow = kwargs.pop('overflow', 'none')
# -> 1015         axes = [self.axis(ax) for ax in axes]
#    1016         reduced_dims = [ax for ax in self._axes if ax not in axes]
#    1017         out = Hist(self._label, *reduced_dims, dtype=self._dtype)
#
# /uscms_data/d3/jennetd/hbb-prod-modes/february-2021/vh-1d-category/coffeaenv/lib/python3.7/site-packages/coffea/hist/hist_tools.py in axis(self, axis_name)
#     798         if axis_name in self._axes:
#     799             return self._axes[self._axes.index(axis_name)]
# --> 800         raise KeyError("No axis %s found in %r" % (axis_name, self))
#     801
#     802     def axes(self):
#
# KeyError: 'No axis pt1 found in <Hist (process,msd1,ddb1,pt2,msd2,n2ddt2) instance at 0x7f444032d350>'

# %%
templates2 = outsum['templates2'].group('dataset', hist.Cat('process', 'Process'), pmap).integrate('region','muoncontrol')

# %%
hist.plot1d(templates2.sum('msd1','etamu').integrate('process','muondata'),overlay='ddb1')

# %%
hist.plot1d(templates2.sum('msd1','ptmu').integrate('process','muondata'),overlay='ddb1')

# %%
hist.plot1d(templates2.sum('ptmu','etamu').integrate('process','muondata'),overlay='ddb1')

# %%
hist.plot1d(templates2.sum('ptmu','etamu').integrate('process','ttbar'),overlay='ddb1')

# %%
def plot_stack(x,name):
    x.label = 'Events'
    axes = hist.plot1d(x, overlay='process', fill_opts={'edgecolor': (0,0,0,1)}, stack=True, order=['ttH','ZH','WH','VBF','ggF','VV','ttbar','singlet','Wjets','Zjets','QCD'])
    axes.set_prop_cycle(cycler(color=colors.values()))
    axes.set_yscale('log')
    axes.set_ylim(.001, 100000)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    
    #png_name = year+'/plot-all/'+name+'_stack.png'
    #plt.savefig(png_name,bbox_inches='tight')
    #pdf_name = year+'/plot-all/'+name+'_stack.pdf'
    #plt.savefig(pdf_name,bbox_inches='tight')

# %%
plot_stack(templates2.sum('ptmu','etamu').integrate('ddb1',int_range=slice(0,0.89)),'msd1')

# %%
plot_stack(templates2.sum('ptmu','etamu').integrate('ddb1',int_range=slice(0.89,1)),'msd1')

# %%
plot_stack(templates2.sum('msd1','etamu').integrate('ddb1',int_range=slice(0,0.89)),'ptmu')

# %%
plot_stack(templates2.sum('msd1','etamu').integrate('ddb1',int_range=slice(0.89,1)),'ptmu')

# %%
plot_stack(templates2.sum('msd1','ptmu').integrate('ddb1',int_range=slice(0,0.89)),'etamu')

# %%
plot_stack(templates2.sum('msd1','ptmu').integrate('ddb1',int_range=slice(0.89,1)),'etamu')
